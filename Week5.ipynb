# %%
romanian_map = {
    'Arad': {'Sibiu':140, 'Zerind':75, 'Timisoara':118},
    'Zerind': {'Arad':75, 'Oradea':71},
    'Oradea': {'Zerind':71, 'Sibiu': 151},
    'Sibiu': {'Arad':140, 'Oradea':151, 'Fagaras':99, 'Rimnicu':80},
    'Timisoara': {'Arad': 118, 'Lugoj':111},
    'Lugoj': {'Timisoara':111, 'Mehadia':70},
    'Mehadia': {'Lugoj': 70, 'Drobeta':75},
    'Drobeta': {'Mehadia':75, 'Craiova':120},
    'Craiova': {'Drobeta': 120, 'Rimnicu': 146, 'Pitesti': 138},
    'Rimnicu': {'Sibiu': 80, 'Craiova': 146, 'Pitesti': 97},
    'Fagaras': {'Sibiu':99, 'Bucharest':211},
    'Pitesti': {'Rimnicu': 97, 'Craiova':138, 'Bucharest':101},
    'Bucharest': {'Fagaras':211, 'Pitesti': 101, 'Giurgiu':90, 'Urziceni':85},
    'Giurgiu': {'Bucharest': 90},
    'Urziceni': {'Bucharest': 85, 'Vaslui':142, 'Hirsova':98},
    'Hirsova': {'Urziceni':98, 'Eforie':86},
    'Eforie': {'Hirsova':86},
    'Vaslui': {'Iasi': 92, 'Urziceni':142},
    'Iasi': {'Vaslui':92, 'Neamt': 87},
    'Neamt': {'Iasi':87}
}

# %% [markdown]
# # Greedy Best First Search

# %%
h = {'Arad': 366,'Zerind':  374,'Oradea': 380,'Sibiu': 253,
    'Timisoara': 329,'Lugoj': 244,'Mehadia': 241,'Drobeta': 242,
    'Craiova': 160,'Rimnicu': 193,'Fagaras': 176,'Pitesti': 100,
    'Bucharest': 0,'Giurgiu': 77,'Urziceni': 80,'Hirsova': 151,
    'Eforie': 161,'Vaslui': 199,'Iasi': 226,'Neamt': 234
}

# %%
from queue import PriorityQueue


def gbfs(startingNode, destinationNode):
    visited = {}
    
    gbfs_traversal_output = []
    pq = PriorityQueue()


    for city in romanian_map.keys():
        visited[city] = False
        
    visited[startingNode] = True
    node = (h[startingNode],startingNode,[startingNode],0)
    pq.put(node)


    while not pq.empty():
        node = pq.get()
        u = node[1] 
        print('Expand--->'+u)
        gbfs_traversal_output.append(u)
        if u== destinationNode:
            print("******************FINAL PATH**********************")
            print()
            print(node[2])
            print("******************TOTAL COST**********************")
            print()
            print(node[3])
            print("******************Traversing Path**********************")
            print()
            print(gbfs_traversal_output)
            break
        visited[u] = True
        for v in romanian_map[u].keys():            
            if not visited[v]:
                print('Current--->'+v)
                d = node[3] + romanian_map[u][v]
                print('**************')
                print(node[3]," + ",romanian_map[u][v]," = ",d)
                print('**************')
                p = node[2]+[v]
                pq.put((h[v],v,p,d))   
    

gbfs('Timisoara', 'Bucharest')
# Out:
# Expand--->Timisoara
# Current--->Arad
# **************
# 0  +  118  =  118
# **************
# Current--->Lugoj
# **************
# 0  +  111  =  111
# **************
# Expand--->Lugoj
# Current--->Mehadia
# **************
# 111  +  70  =  181
# **************
# Expand--->Mehadia
# Current--->Drobeta
# **************
# 181  +  75  =  256
# **************
# Expand--->Drobeta
# Current--->Craiova
# **************
# 256  +  120  =  376
# **************
# Expand--->Craiova
# Current--->Rimnicu
# **************
# 376  +  146  =  522
# **************
# Current--->Pitesti
# **************
# 376  +  138  =  514
# **************
# Expand--->Pitesti
# Current--->Rimnicu
# **************
# 514  +  97  =  611
# **************
# Current--->Bucharest
# **************
# 514  +  101  =  615
# **************
# Expand--->Bucharest
# ******************FINAL PATH**********************
#
# ['Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti', 'Bucharest']
# ******************TOTAL COST**********************
#
# 615
# ******************Traversing Path**********************
#
# ['Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti', 'Bucharest']

# %%
# A*

# %%
from queue import PriorityQueue

def gbfs(startingNode, destinationNode):
    visited = {}
    
    gbfs_traversal_output = []
    pq = PriorityQueue()


    for city in romanian_map.keys():
        visited[city] = False
        
    visited[startingNode] = True
    node = (h[startingNode],startingNode,[startingNode],0)
    pq.put(node)

    while not pq.empty():
        node = pq.get()
        u = node[1] 
        print('Expand-->'+u)
        print(node[3])
        print('-----')
        gbfs_traversal_output.append(u)
        if u== destinationNode:
            print("******************FINAL PATH**********************")
            print()
            print(node[2])
            print("******************TOTAL COST**********************")
            print()
            print(node[3])
            print("******************Traversing Path**********************")
            print()
            print(gbfs_traversal_output)
            break
        visited[u] = True
        for v in romanian_map[u].keys():
            
            if not visited[v]:
                print('Current---->'+v)
                print('HEURISTIC VALUE of current node')
                print(h[v])
                print('END')
                d = node[3] + romanian_map[u][v] 
                l=h[v]+d
                print('************')
                print(node[3]," + ",romanian_map[u][v]," = ",d)
                print("Total Cost(h[v]+d)",l)
                print('************')
                p = node[2]+[v]
                pq.put((l,v,p,d))   
    

gbfs('Timisoara', 'Bucharest')
# Out:
# Expand-->Timisoara
# 0
# -----
# Current---->Arad
# HEURISTIC VALUE of current node
# 366
# END
# ************
# 0  +  118  =  118
# Total Cost(h[v]+d) 484
# ************
# Current---->Lugoj
# HEURISTIC VALUE of current node
# 244
# END
# ************
# 0  +  111  =  111
# Total Cost(h[v]+d) 355
# ************
# Expand-->Lugoj
# 111
# -----
# Current---->Mehadia
# HEURISTIC VALUE of current node
# 241
# END
# ************
# 111  +  70  =  181
# Total Cost(h[v]+d) 422
# ************
# Expand-->Mehadia
# 181
# -----
# Current---->Drobeta
# HEURISTIC VALUE of current node
# 242
# END
# ************
# 181  +  75  =  256
# Total Cost(h[v]+d) 498
# ************
# Expand-->Arad
# 118
# -----
# Current---->Sibiu
# HEURISTIC VALUE of current node
# 253
# END
# ************
# 118  +  140  =  258
# Total Cost(h[v]+d) 511
# ************
# Current---->Zerind
# HEURISTIC VALUE of current node
# 374
# END
# ************
# 118  +  75  =  193
# Total Cost(h[v]+d) 567
# ************
# Expand-->Drobeta
# 256
# -----
# Current---->Craiova
# HEURISTIC VALUE of current node
# 160
# END
# ************
# 256  +  120  =  376
# Total Cost(h[v]+d) 536
# ************
# Expand-->Sibiu
# 258
# -----
# Current---->Oradea
# HEURISTIC VALUE of current node
# 380
# END
# ************
# 258  +  151  =  409
# Total Cost(h[v]+d) 789
# ************
# Current---->Fagaras
# HEURISTIC VALUE of current node
# 176
# END
# ************
# 258  +  99  =  357
# Total Cost(h[v]+d) 533
# ************
# Current---->Rimnicu
# HEURISTIC VALUE of current node
# 193
# END
# ************
# 258  +  80  =  338
# Total Cost(h[v]+d) 531
# ************
# Expand-->Rimnicu
# 338
# -----
# Current---->Craiova
# HEURISTIC VALUE of current node
# 160
# END
# ************
# 338  +  146  =  484
# Total Cost(h[v]+d) 644
# ************
# Current---->Pitesti
# HEURISTIC VALUE of current node
# 100
# END
# ************
# 338  +  97  =  435
# Total Cost(h[v]+d) 535
# ************
# Expand-->Fagaras
# 357
# -----
# Current---->Bucharest
# HEURISTIC VALUE of current node
# 0
# END
# ************
# 357  +  211  =  568
# Total Cost(h[v]+d) 568
# ************
# Expand-->Pitesti
# 435
# -----
# Current---->Craiova
# HEURISTIC VALUE of current node
# 160
# END
# ************
# 435  +  138  =  573
# Total Cost(h[v]+d) 733
# ************
# Current---->Bucharest
# HEURISTIC VALUE of current node
# 0
# END
# ************
# 435  +  101  =  536
# Total Cost(h[v]+d) 536
# ************
# Expand-->Bucharest
# 536
# -----
# ******************FINAL PATH**********************
#
# ['Timisoara', 'Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest']
# ******************TOTAL COST**********************
#
# 536
# ******************Traversing Path**********************
#
# ['Timisoara', 'Lugoj', 'Mehadia', 'Arad', 'Drobeta', 'Sibiu', 'Rimnicu', 'Fagaras', 'Pitesti', 'Bucharest']

# %% [markdown]
# # Uniform Cost Search

# %%
from queue import PriorityQueue


def ucs(startingNode, destinationNode):
    visited = {}
    
    ucs_traversal_output = []
    pq = PriorityQueue()


    for city in romanian_map.keys():
        visited[city] = False
        
    visited[startingNode] = True
    node = (0,startingNode,[startingNode])
    pq.put(node)


    while not pq.empty():
        node = pq.get()
        u = node[1]    
        ucs_traversal_output.append(u)
        if u== destinationNode:
            print("******************FINAL PATH**********************")
            print()
            print(node[2])
            print("******************TOTAL COST**********************")
            print()
            print(node[0])
            print("******************Traversing Path**********************")
            print()
            print(ucs_traversal_output)
            break
        visited[u] = True
        for v in romanian_map[u].keys():            
            if not visited[v]:
                d = node[0] + romanian_map[u][v]
                print("Cost",d)
                p = node[2]+[v]
                print("PATH",p)
                pq.put((d,v,p)) 

ucs('Timisoara', 'Bucharest')
# Out:
# Cost 118
# PATH ['Timisoara', 'Arad']
# Cost 111
# PATH ['Timisoara', 'Lugoj']
# Cost 181
# PATH ['Timisoara', 'Lugoj', 'Mehadia']
# Cost 258
# PATH ['Timisoara', 'Arad', 'Sibiu']
# Cost 193
# PATH ['Timisoara', 'Arad', 'Zerind']
# Cost 256
# PATH ['Timisoara', 'Lugoj', 'Mehadia', 'Drobeta']
# Cost 264
# PATH ['Timisoara', 'Arad', 'Zerind', 'Oradea']
# Cost 376
# PATH ['Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova']
# Cost 409
# PATH ['Timisoara', 'Arad', 'Sibiu', 'Oradea']
# Cost 357
# PATH ['Timisoara', 'Arad', 'Sibiu', 'Fagaras']
# Cost 338
# PATH ['Timisoara', 'Arad', 'Sibiu', 'Rimnicu']
# Cost 484
# PATH ['Timisoara', 'Arad', 'Sibiu', 'Rimnicu', 'Craiova']
# Cost 435
# PATH ['Timisoara', 'Arad', 'Sibiu', 'Rimnicu', 'Pitesti']
# Cost 568
# PATH ['Timisoara', 'Arad', 'Sibiu', 'Fagaras', 'Bucharest']
# Cost 514
# PATH ['Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti']
# Cost 536
# PATH ['Timisoara', 'Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest']
# Cost 615
# PATH ['Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti', 'Bucharest']
# ******************FINAL PATH**********************
#
# ['Timisoara', 'Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest']
# ******************TOTAL COST**********************
#
# 536
# ******************Traversing Path**********************
#
# ['Timisoara', 'Lugoj', 'Arad', 'Mehadia', 'Zerind', 'Drobeta', 'Sibiu', 'Oradea', 'Rimnicu', 'Fagaras', 'Craiova', 'Oradea', 'Pitesti', 'Craiova', 'Pitesti', 'Bucharest']
